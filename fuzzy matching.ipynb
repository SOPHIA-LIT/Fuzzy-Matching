# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ddb0c3c3-006c-47ca-85cf-cf124b77aba4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ddb0c3c3-006c-47ca-85cf-cf124b77aba4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving master.csv to master (1).csv

# %%
import io
df1 = pd.read_csv(io.BytesIO(uploaded['master.csv']))

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-83598e86-0460-4994-96df-e75defa38ab1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83598e86-0460-4994-96df-e75defa38ab1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 18.csv to 18 (1).csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['18.csv']))

# %%
# !pip install fuzzy_pandas

# %%
import fuzzy_pandas as fpd

# %%
matches = fpd.fuzzy_merge(df1, df2,
                          left_on=['firm'],
                          right_on=['firm'],
                          keep_left=['id','firm'],
                          keep_right=['year','score','firm'],
                          method= 'metaphone')

# %%
print (matches)
# Out:
#         id  ...                                       firm
# 0    29703  ...                  balmer lawrie &  co. ltd.
# 1    33721  ...                       bharat dynamics ltd.
# 2    33723  ...                                  beml ltd.
# 3    33727  ...                   bharat electronics  ltd.
# 4    33769  ...             bharat iieavy electricals ltd.
# 5    48799  ...                            coal india ltd.
# 6    48799  ...                          gail (india) ltd.
# 7    48960  ...                       cochin shipyard ltd.
# 8    68332  ...                       engineers india ltd.
# 9    79498  ...                            coal india ltd.
# 10   79498  ...                          gail (india) ltd.
# 11   88770  ...                                   hmt ltd.
# 12   93954  ...                hindustan  aeronautics ltd.
# 13   94000  ...                      hindustan copper ltd.
# 14   94033  ...              hindustan  fluorocarbons ltd.
# ...

# %%
df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')

# %%
from IPython.display import HTML
import numpy as np

# %%
create_download_link(filename='matches.csv')
# Out:
# <a href=matches.csv>Download CSV file</a>

# %%
def create_download_link(title = "Download CSV file", filename = "matches.csv"):  
    html = '<a href={filename}>{title}</a>'
    html = html.format(title=title,filename=filename)
    return HTML(html)
